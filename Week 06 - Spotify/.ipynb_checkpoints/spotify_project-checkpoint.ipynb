# %%
import config
import spotipy
import json
import pprint
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import IFrame
from spotipy.oauth2 import SpotifyClientCredentials

import pickle
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn import datasets # sklearn comes with some toy datasets to practice
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id = config.client_id,
    client_secret = config.client_secret)
)

# %%
# Scrape list of hot songs

url = "https://www.billboard.com/charts/hot-100/"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.content, 'html.parser')

titles = []
for title in soup.select('h3.c-title.a-no-trucate'):
    titles.append(title.get_text(strip=True))

artists = []
for artist in soup.select('span.c-label.a-no-trucate'):
    artists.append(artist.get_text(strip=True))

hot_songs = pd.DataFrame({'title': titles, 'artist': artists})
hot_songs.head(100)
# Out:
#                     title                                artist
# 0      Paint The Town Red                              Doja Cat
# 1   I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# 2                Fast Car                            Luke Combs
# 3            Cruel Summer                          Taylor Swift
# 4              Last Night                         Morgan Wallen
# ..                    ...                                   ...
# 95            Stand By Me      Lil Durk Featuring Morgan Wallen
# 96      Call Your Friends                              Rod Wave
# 97     Your Heart Or Mine                             Jon Pardi
# 98           Primera Cita                            Carin Leon
# 99                    S91                               Karol G
#
# [100 rows x 2 columns]

# %%
def play_song(track_id):
    track = sp.track(track_id)
    print()
    print('-',track['name'],'by',track['artists'][0]['name'],'-')
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
    )

# %%
def suggest_new_song():
    if result['tracks']['items'][0]['name'] in list(hot_songs['title']):
        print("You chose a hot song, here is another popular one:")
        title = hot_songs.sample()['title'].array[0]
        print(title)
        recommended = sp.search(q=title,limit=1)
        return play_song(recommended['tracks']['items'][0]['id'])
    else:
        print("You chose a great song, here is a similar one you may like: ")
        
        # Find the cluster of the input audio
        input_audio = sp.audio_features(result['tracks']['items'][0]['id'])[0]
        X_test = pd.DataFrame(input_audio, index=[0])
        X_test = X_test.select_dtypes(include=np.number)
        X_test_scaled = scaler.transform(X_test)
        X_test_scaled_df = pd.DataFrame(X_test_scaled, columns = X_test.columns)
        cluster = kmeans.predict(X_test_scaled_df)
        
        # Filter the X_total for the same cluster and suggest a sample
        filtered_X = X_total[X_total['cluster'] == cluster[0]]
        suggestion_id = filtered_X.sample()['id'].array[0]
        return play_song(suggestion_id)

# %%
# Import audio features of 5532 scraped songs
X_total = pd.read_csv('audio_features.csv', index_col=[0])
X = X_total.select_dtypes(include=np.number)

# Scale audio features
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)

# %%
K = range(2, 21)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)
    
plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(X_scaled_df)
    
    filename = "model/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
model = KMeans(12, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
visualizer.show()
# Out:
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 5532 Samples in 12 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
# Train the K-means model
kmeans = KMeans(n_clusters=37, random_state=42)
kmeans.fit(X_scaled_df)
# Out:
# /Users/frussen/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=37, random_state=42)

# %%
clusters = kmeans.predict(X_scaled_df)
X_total["cluster"] = clusters
clusters

# Same:
# labels = kmeans.labels_
# X_total["cluster"] = labels
# labels
# Out:
# array([18, 23, 25, ...,  0, 23, 14], dtype=int32)

# %%
#
#
#
#
#
#
#
#
#                                   SONG RECOMMENDER
#                                     HERE IT IS!!
#
#
#
#
#
#
#
#
#
#

# %%
# Ask user for a song
input_song = input("Insert the name of a song: ")
# Out:
# Insert the name of a song: smooth criminal

# %%
result = sp.search(q=input_song,limit=1)
play_song(result['tracks']['items'][0]['id'])
# Out:
# - Smooth Criminal by Alien Ant Farm -
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/5z6xHjCZr7a7AIcy8sPBKy?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
suggest_new_song()
# Out:
# You chose a great song, here is a similar one you may like:
#
# - Hymn for the Weekend by Coldplay -
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3RiPr603aXAoi4GHyXx0uy?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
