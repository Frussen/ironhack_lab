# %%
import config
import spotipy
import json
import pprint
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id= config.client_id,
    client_secret= config.client_secret)
)

# %%
playlists = []
for i in range(23):
    playlists.extend(sp.user_playlists('Spotify', limit=50, offset=i*50)['items'])
len(playlists)
#pprint.pprint(playlists[0])
# Out:
# 1112

# %%
playlist_ids = []
for playlist in playlists:
    playlist_ids.append(playlist['id'])
len(playlist_ids)
#playlist_ids
# Out:
# 1112

# %%
song_ids = []

for playlist_id in playlist_ids:
    playlist_songs = sp.user_playlist_tracks("spotify", playlist_id, market="US", limit=5)['items']
    while None in playlist_songs:
        playlist_songs.remove(None)
    for song in playlist_songs:
        try:
            song_ids.append(song['track']['id'])
        except TypeError:
            print("---- ", song)
            pass

len(song_ids)
# Out:
# ----  {'added_at': '2023-08-21T15:41:01Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}, 'is_local': False, 'primary_color': None, 'track': None, 'video_thumbnail': {'url': None}}
# 5542

# %%
audio_list = []
for song_id in song_ids:
    try:
        audio_list.append(sp.audio_features(song_id)[0])
    except TypeError:
        pass
    
while None in audio_list:
    audio_list.remove(None)
len(audio_list)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:879, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     878 try:
# --> 879     retries = retries.increment(method, url, response=response, _pool=self)
#     880 except MaxRetryError:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=2gyxAWHebV7xPYVxqoi86f (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:511, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     510 if isinstance(e.reason, ResponseError):
# --> 511     raise RetryError(e, request=request)
#     513 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=2gyxAWHebV7xPYVxqoi86f (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[6], line 4
#       2 for song_id in song_ids:
#       3     try:
# ----> 4         audio_list.append(sp.audio_features(song_id)[0])
#       5     except TypeError:
#       6         pass
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:1734, in Spotify.audio_features(self, tracks)
#    1732 if isinstance(tracks, str):
#    1733     trackid = self._get_id("track", tracks)
# -> 1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:307, in Spotify._internal_call(self, method, url, payload, params)
#     305     except (IndexError, AttributeError):
#     306         reason = None
# --> 307     raise SpotifyException(
#     308         429,
#     309         -1,
#     310         "%s:\n %s" % (request.path_url, "Max Retries"),
#     311         reason=reason
#     312     )
#     313 except ValueError:
#     314     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=2gyxAWHebV7xPYVxqoi86f:
#  Max Retries, reason: too many 429 error responses

# %%
audio_features_df = pd.DataFrame(list(audio_list))
audio_features_df

# %%
sp.audio_features(song_ids[0])[0]
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~/anaconda3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~/anaconda3/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#
# File ~/anaconda3/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1129 if buffer is not None:
# -> 1130     return self._sslobj.read(len, buffer)
#    1131 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     469     raise
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:357, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     356 if isinstance(err, SocketTimeout):
# --> 357     raise ReadTimeoutError(
#     358         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     359     )
#     361 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     362 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sp.audio_features(song_ids[0])[0]
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:1734, in Spotify.audio_features(self, tracks)
#    1732 if isinstance(tracks, str):
#    1733     trackid = self._get_id("track", tracks)
# -> 1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:533, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     531     raise SSLError(e, request=request)
#     532 elif isinstance(e, ReadTimeoutError):
# --> 533     raise ReadTimeout(e, request=request)
#     534 elif isinstance(e, _InvalidHeader):
#     535     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)

# %%
song_ids
# Out:
# ['2gyxAWHebV7xPYVxqoi86f',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '1vYXt7VSjH9JIM5oRRo7vA',
#  '7x9aauaA9cu6tyfpHnqDLo',
#  '67nepsnrcZkowTxMWigSbb',
#  '4367dXCt02KMgELPisJ2D4',
#  '1L0OmJV0LnPDWuHCIGmBV6',
#  '4YQImHflXSiIMXntcwPkx8',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '2GAqIzPU7v3kfvY4hZQ9jm',
#  '4bARASJEokNacSYtEhoNBp',
#  '59uQI0PADDKeE6UZDTJEe8',
#  '7qaMlLPdwNiiU1Uiy1oAdO',
#  '2KtGiBi5CrX2ERPD2PAS34',
#  '3XB5uhhlYSnkxpSihkNQwh',
#  '6XbtvPmIpyCbjuT0e8cQtp',
#  '7ABLbnD53cQK00mhcaOUVG',
#  '7ro0hRteUMfnOioTFI5TG1',
#  '0QRHOAeU8JRaVVn3UoZBih',
#  '4YQImHflXSiIMXntcwPkx8',
#  '2gyxAWHebV7xPYVxqoi86f',
#  '39fD0qvjgk8RarJnoBiDTx',
#  '1exDZN0zsfDpsIKamOqmSz',
#  '7CYYZVnDYoUtNlSxNNz4P9',
#  '5hFkGfx038V0LhqI0Uff2J',
#  '3RI7rnK1YgmyRcXq9pkMqQ',
#  '7hVcd9PDdO0xK8vE3WQqnV',
#  '6fjZ39b5dT9uZzFsVRLwSi',
#  '1b1A6Z7pI8myEX3TSyweOk',
#  '6sg284TefDkBpFh0317Agp',
#  '58WSKtcvVt208XY8tolYQI',
#  '7DswEZZthZ6piQpL25qGAM',
#  '0J1YRLYhTG1MBosjidD7OI',
#  '66PVdnWWemyJbvScVS6vJ0',
#  '5EWPGh7jbTNO2wakv8LjUI',
#  '7snQQk1zcKl8gZ92AnueZW',
#  '1bp2IO61zbQrbWNmKKxg3f',
#  '0ofHAoxe9vBkTCp2UQIavz',
#  '7tFiyTwD0nx5a1eklYtX2J',
#  '7mobUfp1aL8A6CdugCMWft',
#  '1aNUSKBe6UMyMk3pEu9ws7',
#  '4heve4ydl1u6V3AD4moZq9',
#  '6tifCCTIVBLC2TmTquYG7G',
#  '59NraMJsLaMCVtwXTSia8i',
#  '0daHbdrLvUmkh81rnolMcG',
#  '3tNMdL4qjzNHfo7rlVMESK',
#  '3l6RgZRKf4FfSc2FJlesEL',
#  '6vWu5uWlox5TVDPl3LvoG3',
#  '7505qe0xzCuDPaILCURnOC',
#  '2gyxAWHebV7xPYVxqoi86f',
#  '4YQImHflXSiIMXntcwPkx8',
#  '5h1BN75CEh8wdSwE1xrbSe',
#  '5WZlorRUxgryaweu7kqeHd',
#  '4heve4ydl1u6V3AD4moZq9',
#  '5fRjEdFAmmZoJFCWLCp6a8',
#  '6pRYZrJTQ8yYvhVfhTZ70Q',
#  '6L89mwZXSOwYl76YXfX13s',
#  '6ORqU0bHbVCRjXm9AjyHyZ',
#  '6nTiIhLmQ3FWhvrGafw2zj',
#  '5GorCbAP4aL0EJ16frG2hd',
#  '7c1Dar0pIAW7w5TzaGjt9t',
#  '3k6L0H08zSY5yRDgqI8fqx',
#  '4Qievb8Mqy0qxdLNVl02zt',
#  '0D7r6CIGNRvs0IvsDOunZr',
#  '5fKZJHzJ9d3MADArbm9muW',
#  '7ygpwy2qP3NbrxVkHvUhXY',
#  '0SlpFHdk4UHBDzCEoXzy14',
#  '6TlQ5fbojNRuG0hPQMbxeW',
#  '5WTPhYmwwojFP73O7p3Izi',
#  '12dU3vAh6AFoJkisorfoUl',
#  '07q0QVgO56EorrSGHC48y3',
#  '6KTv0Z8BmVqM7DPxbGzpVC',
#  '1brpdmqkx3kSxyqzqXfW7J',
#  '4Q9WS9ARvL7rkokSbnhM96',
#  '2o4u19nlQWOGg5mLanT7Pg',
#  '18zG4sti0gnHNnobLOBjmr',
#  '14FW5L81Px03LnnsXnB2LG',
#  '4LltjSEOq80cOSFeIM6LOz',
#  '7aOor99o8NNLZYElOXlBG1',
#  '10jugZSxm3weVkTSSO8LFR',
#  '5ghIJDpPoe3CfHMGu71E6T',
#  '1FkoVC85Ds3mFoK0fVqEqP',
#  '59WN2psjkt1tyaxjspN8fp',
#  '6L89mwZXSOwYl76YXfX13s',
#  '3d9DChrdc6BOeFsbrZ3Is0',
#  '4alv8RaCCKQAShJ9Xya9w7',
#  '7BkLfZnv7DJdJJ9wWj8Vdv',
#  '39sDitIeCMrVX2QyXHY46t',
#  '3USxtqRwSYz57Ewm6wWRMp',
#  '0rVJ6v23RQozOIvr1YotJP',
#  '6bLU8e0LGyztE9iD5DWBQ1',
#  '79vEv8zqy9tLYsTxxkXHXq',
#  '3USxtqRwSYz57Ewm6wWRMp',
#  '6G1Mz5yMgn0ydOlIvTrZ65',
#  '6K4t31amVTZDgR3sKmwUJJ',
#  '6KPjAsDsH425JhWiHAWHOK',
#  '24TzmWrz2HHWV3UO5PlvNb',
#  '4CaM2lWgvmWLIBDOkJCD7p',
#  '2OLaeJRrRjFgLfTsccnzlM',
#  '5pbvXAfrjtRwfwcKGPAZma',
#  '507bYMYfbm6sUS9iEAaeSd',
#  '2CtemffYhT0DJWcT1XW047',
#  '6bo13cPb5M0B6LhQEl0A3E',
#  '19dNZyDyw00aKgr6S0Os6e',
#  '58AwxWLaRHn2lTqqH9dLkU',
#  '4uBs8miGwBykRYjrbAO5kV',
#  '3EjHI10QuKMoVBxcgpHrf3',
#  '2vfGITBrVJaPYSgKaKJv9Z',
#  '5bUNcdF18WBwCdkRNO4y5C',
#  '7sCMZKSjZbx563QSkqxTqC',
#  '3IV4swNduIRunHREK80owz',
#  '6nJPHXRpKYv2yqtalEjKy5',
#  '3K4HG9evC7dg3N0R9cYqk4',
#  '2DlHlPMa4M17kufBvI2lEN',
#  '1wqKQu5RECFt8Q3MMCqWdn',
#  '6lF9MVbhNfe0EZcACAdaFM',
#  '5i6L129avGeLGlfJ6bLKUN',
#  '2PYZj3AqpS6Vtr4ghoe8eV',
#  '30KHfXcIfKyiDBojwclxy7',
#  '5aIVCx5tnk0ntmdiinnYvw',
#  '4RoKNqyZ9622tcAeNPNv5k',
#  '58WSKtcvVt208XY8tolYQI',
#  '19Bk7ulfjk4Vg4PMS38UGc',
#  '1VEPKq5jNdUyemcq29h5ki',
#  '4iZ4pt7kvcaH6Yo8UoZ4s2',
#  '3xKsf9qdS1CyvXSMEid6g8',
#  '5IgjP7X4th6nMNDh4akUHb',
#  '3EaJDYHA0KnX88JvDhL9oa',
#  '1xzi1Jcr7mEi9K2RfzLOqS',
#  '5ye1TParxcolbnNsOXO8qE',
#  '0YMe6PHRbeDcN7KJdCG0bW',
#  '5d2sBOqleqxg8noBOvQEYa',
#  '2X3noddA1Gi8OmJVRP4eYC',
#  '7tzeZLMnqlke2raEMeDZ9S',
#  '5i6L129avGeLGlfJ6bLKUN',
#  '23VB6t2KnNL1l38ZZC8c37',
#  '64TJKMfx0QxpuR7rTXL05c',
#  '2PYZj3AqpS6Vtr4ghoe8eV',
#  '4VfjUbKtTaZsQriNud6Iz2',
#  '6lbXUz3ysZWYSbBFGiPgXJ',
#  '5YE4SCAxoR32l4PDYSBWOo',
#  '0Q0IVlqMV64kNLlwjPj0Hl',
#  '6V3J9NK2BK2KbwmkGgTjip',
#  '0loJyuSFr6vVPBQSmLLrrQ',
#  '1wqKQu5RECFt8Q3MMCqWdn',
#  '5oCRONUj1i5wNH4XM5lPSl',
#  '3ZrfIcsDKTBZzCwlE59yiS',
#  '1axghhfOmj6V4vPCbJtSqX',
#  '6lB0AAe5f8msn8vqUNkVsN',
#  '4PEGwWH4tL6H7dGl4uVSPg',
#  '7ySbfLwdCwl1EM0zNCJZ38',
#  '6l4TNbfPtNAOOlGIfceSaO',
#  '4lRrk574qIHpoEEKC1zuam',
#  '3kVIFDE3G89I2RPVkiRaRj',
#  '4iuNZTcvT9diFySSzVsnVS',
#  '3c6afiysmB7OnxQzzSqRfD',
#  '6N3qHjcwly8ZuhE4bPYJAX',
#  '2fE4MbwX3QGMzNaMjGVhtw',
#  '1Dx8rIZaXzZPvUQRF2j9hB',
#  '7vqC1Vkr5f9a7CylkjUkPW',
#  '0ToGha42fy4KqBdzJ1yOTN',
#  '1pAyPMHDHBOR3zlTK1eUb4',
#  '736A53Kw337Z5zrJhH24jP',
#  '6cwhJE7pYWON7vv9kwVvEt',
#  '5uuJruktM9fMdN9Va0DUMl',
#  '32OlwWuMpZ6b0aN2RZOeMS',
#  '2je56j0xuoTi1gYkLLMlJU',
#  '4yQw7FR9lcvL6RHtegbJBh',
#  '2dCmGcEOQrMQhMMS8Vj7Ca',
#  '0uEp9E98JB5awlA084uaIg',
#  '1KGi9sZVMeszgZOWivFpxs',
#  '3XKIUb7HzIF1Vu9usunMzc',
#  '6MdqqkQ8sSC0WB4i8PyRuQ',
#  '2VjXGuPVVxyhMgER3Uz2Fe',
#  '2tUBqZG2AbRi7Q0BIrVrEj',
#  '1Hv1VTm8zeOeybub15mA2R',
#  '3koCCeSaVUyrRo3N2gHrd8',
#  '3nFJbZCHP4d9vduKjJLdBL',
#  '3SnGymj6ijE2iuUfWxLo1q',
#  '49FYlytm3dAAraYgpoJZux',
#  '0W4NhJhcqKCqEP2GIpDCDq',
#  '5IVuqXILoxVWvWEPm82Jxr',
#  '3XVBdLihbNbxUwZosxcGuJ',
#  '3aw9iWUQ3VrPQltgwvN9Xu',
#  '7DswEZZthZ6piQpL25qGAM',
#  '5Y0E3dOeynKuLDAXu0t0Bg',
#  '1sSuFkO3m3Cr6YN24NYol5',
#  '2dOUErBzFZJ8l7MbV6FcYW',
#  '6KS5iyM4uDuJ6oAacMSXha',
#  '7yMhyRmQGv6mSD6SkfhPeF',
#  '7CRPXJt3IVC7V0VcM0PSQi',
#  '44s8AnWjkj68J5N9JKX8Zw',
#  '2RISD4aJrioDB54exm5WWM',
#  '0YclWqGe9XpQBx3gwAyyJJ',
#  '2bI6KAUqXeIXGAEEvup8ri',
#  '5Ir9mqfAUnXkSkXHF1yvM0',
#  '5BoA4ehsprvSzDBuFOPgdA',
#  '67eYAnkdTu8BMcIx29z26L',
#  '2JCFm7pOuEP0cItCq6t3bd',
#  '4zPVMv84MMHehLNZYIS1Zv',
#  '6MxXe1BRJMl1Bu1NB1oKwU',
#  '5js0S06HeHofz7ZtlXV7In',
#  '7iXLa8DhoOyxB6UQ1iEt5h',
#  '6xp1u6ZEHXX8DxJIFFrVoP',
#  '3YfGTvsTAWGC2lgoDOikUz',
#  '1UPHCP5YeVfele4DMbdGyi',
#  '1aNUSKBe6UMyMk3pEu9ws7',
#  '09rAJ1Q1NNJSaUKEW3X9P6',
#  '0zKbDrEXKpnExhGQRe9dxt',
#  '0vQ2LIvx5U6QN7BnUHWwsJ',
#  '1aNUSKBe6UMyMk3pEu9ws7',
#  '6tifCCTIVBLC2TmTquYG7G',
#  '3Q4DJp31Dat8RoPN3KwpJy',
#  '1XgsBtX1glXMrclgp6JBb5',
#  '5WZlorRUxgryaweu7kqeHd',
#  '4heve4ydl1u6V3AD4moZq9',
#  '7uEvezzgCoYmqRDloOXUSR',
#  '2JCFm7pOuEP0cItCq6t3bd',
#  '0hUU81fjvfcvaiCCN51oRy',
#  '4zbInBD4rY7tYPJ16LVxdh',
#  '3R1618eXJB4mMxIZzLv3Ac',
#  '4p16E9c9Ig6xFMGS3Y82mT',
#  '0biZ6lxXHy4eHweTbOD33W',
#  '2s7F8qjzm1XcMKG7O4GzCY',
#  '0ObzkSnoXbfcJxOjwG09u0',
#  '3tX9hPhKxKBusddqCTWZo4',
#  '0HkqBi1na692hJl5nrTDit',
#  '69uPNh3b6VKdMZMbIKYQ1l',
#  '0NDlsZ7UP5jNf9RjhLOZPA',
#  '4XeIiGpUBshIfs9yrBDVZC',
#  '40tPP3K10yMZxwnT65REKj',
#  '6ziqWx82jgkQYhyIALoraH',
#  '5s0S3Y5Ciq1suPbzRCKYpo',
#  '58kUEj9sd9Z2XIPh3BhJRR',
#  '6vOane9RzzOIITCvbHJ6m2',
#  '2xlSM0k9SCoG6UMaZWWRiC',
#  '5cGBQ9W3XtRuRQFgDklDrI',
#  '3VpxEo6vMpi4rQ6t2WVVkK',
#  '200DiJQhDi69nkGXOrrJgn',
#  '3u5N55tHf7hXATSQrjBh2q',
#  '5XVjNRubJUW0iPhhSWpLCj',
#  '0DiWol3AO6WpXZgp0goxAV',
#  '1xNcBAoUw8Hz6LqK2jt4Ff',
#  '3aQz0z86zrKjd1mcZlonxE',
#  '2MV9MRVSXNTIS3ny31cx9c',
#  '2BOqDYLOJBiMOXShCV1neZ',
#  '5NGS1jwlMxkdCVLG1stGRY',
#  '5aXfGM7WVcqyAvqnL7k0y3',
#  '5vUNRJsvEOUsz4sbKkJpFr',
#  '2Vmmht4V3AOxUAw9KxcluE',
#  '1SCiaEWrW8y8mEEFoQ3RO7',
#  '5xWn1sBr3ZkFOSUrfp6Iz4',
#  '5CM41rtmp3whRZX68O8IR8',
#  '6bRN5rydcVIaLavxqMwZEm',
#  '23RoR84KodL5HWvUTneQ1w',
#  '4uUG5RXrOk84mYEfFvj3cK',
#  '59NraMJsLaMCVtwXTSia8i',
#  '2bgGETGKhv7V0WwQzzWqwc',
#  '51FvjPEGKq2zByeeEQ43V9',
#  '0H2idlyIDxyotmpAJ2NUeh',
#  '7LMsAia3rSvaNrHjgfuJzB',
#  '67f7gMWZ2PJI7IsUBs3mNQ',
#  '2slr1WHisMcjKMEz0RJ8u2',
#  '6I7nESv5d9zf9DcEA9I25u',
#  '23RoR84KodL5HWvUTneQ1w',
#  '3BKD1PwArikchz2Zrlp1qi',
#  '59NraMJsLaMCVtwXTSia8i',
#  '3xIMkM5LgbVDkpO74O3Np3',
#  '5eTaQYBE1yrActixMAeLcZ',
#  '2MoWNYaX0UT7TKbCCx2DsP',
#  '5Gggw8WykNhnZsYExUVYxy',
#  '556awMv4WQP0h1VXMU8rSU',
#  '0gU1afVwFWTspbHNot3yLa',
#  '4QcfHUpGxGGKh7VIVs3LYI',
#  '675uQstqHDJVNwUpMHMY4S',
#  '6iBL6TOzsO75Yz0cG1MO0o',
#  '7LY4ORM47R1YR1Jowwzg8o',
#  '321NLHCw7fk329HwnpDw9S',
#  '5PzIVypjkmW2oJ9arHKa0D',
#  '6zSpb8dQRaw0M1dK8PBwQz',
#  '3YgtkOxZsTuaZdL8McA1FQ',
#  '3YfGTvsTAWGC2lgoDOikUz',
#  '6xp1u6ZEHXX8DxJIFFrVoP',
#  '7MIhUdNJtaOnDmC5nBC1fb',
#  '65ES1qwOB577ZnTkizMXJJ',
#  '47kEJq44ZBrRBD4gvdCu0v',
#  '6oosMYrpIekDxg67SV60Va',
#  '4p16E9c9Ig6xFMGS3Y82mT',
#  '5WsSAyixmdLYcl3FRMjZM1',
#  '0t0FRj21IhRtgxbV5BNf1b',
#  '1YR94xmVWP4Y4t8jojuFow',
#  '4hriybgE67pyiH6yz7J8R5',
#  '0LdAEUc7gyEY6xIG9y3lLM',
#  '2DSQvvaojC1yu5phfWDKuB',
#  '0q9YhUuxm8G1UatNDgBAdh',
#  '6sr4lbYR7Nzpsrf1c0t9Cu',
#  '5BoA4ehsprvSzDBuFOPgdA',
#  '3FrlcqYxS1A3W7pCGAHai6',
#  '2aiy3gAjU8yynkrbpEVQm9',
#  '3zFsJdVCu29em7VUB3Ujqp',
#  '59xRzYdesxyCMhRFaodWNi',
#  '4b2rlKIqyLxpxoIaG7sZ5K',
#  '3IJRNwpqZU7uJhQ5qFvy5D',
#  '6gs5VDiNpbBfXHsAj2c9SB',
#  '5JEaCJCehAtt1nQf0gd9Dx',
#  '2dwU9cQumllxZFtXgautY4',
#  '2gL3yeSrVcdgYUgebT6TKN',
#  '0dZ8mcRlvdvHfUEwxPkb5B',
#  '6TqYadgz6qObDRYkcQe21L',
#  '0e5hNZrUwqeKua0GJHPQFp',
#  '3a3YhO3gL4WaiQCkLVAY01',
#  '2PqmZr6uk48GxTmvZRYjfd',
#  '6ZvL9vA6ZbSCNdpgdYjW12',
#  '6tLoYXdgMy80QaS49kg9z9',
#  '3NeSlNBRvB4BMrxhA88Zke',
#  '7tAGnxLiQTU0EjezyOjUj2',
#  '2F2p7b5Xq20mRyEeWYaeUF',
#  '4rf0IVQDFjr27T4sgah5Pf',
#  '3q696Hv2mRNvnlJGARCBQU',
#  '2DjZ7Ytv2UDKXSoQXTXPkN',
#  '2PqmZr6uk48GxTmvZRYjfd',
#  '6GomT970rCOkKAyyrwJeZi',
#  '0w7JPlp7eEQI2EKW3ayXrv',
#  '6BwPstqf4RoRMbDidFWNxE',
#  '1VSbfnWlHajs3Wz9LhucLB',
#  '080nzaT9PWCqMfFSpjRDHK',
#  '53QLyfbHqEtXK0ys7YW2Q4',
#  '2Ju181y8kKeGQLTwnPNUoN',
#  '5GbMPtLwGNWVAtT0u4SXCg',
#  '3vSYtWxpOfhp54VGGxCZrn',
#  '7jJDybHOdsOxKvM90HRDFu',
#  '5Kwy6gGIkpAyBDqmSokJOx',
#  '59cFhnC1ZxXKvPIF1Y66fj',
#  '3QwYSJpsLN0qannLsQqdVE',
#  '4bz8Z7squfs2Yji2DwoujR',
#  '78zqqw3oLhwiifmbqHoBaN',
#  '6pyjUNNPUAHqRkvD0ZEDFz',
#  '7K9ZxHYSwVJ1BTC044EUNw',
#  '0fK4NmIDXetjIiZ2Oxz2tF',
#  '5eTaQYBE1yrActixMAeLcZ',
#  '04BNQFaBlFF7WDeTb1V0AP',
#  '6wgmzw64fvWGVNfDRbOHFh',
#  '3YgtkOxZsTuaZdL8McA1FQ',
#  '6POZ7ocsOQQvJrfArz6KOD',
#  '3W9xukFv9kGLkLbEe2YITe',
#  '2vk63a0DpsEDiCG4k0mjCF',
#  '6AoG52kxfptY0QBQnjuQOe',
#  '450ieMdH9byHoYTXfx8ORV',
#  '2s7F8qjzm1XcMKG7O4GzCY',
#  '2QUjCgRuF6grKzr4mINjs8',
#  '22MfEGdH3Noyx9GfyZWpFz',
#  '2FEUloDXMvRnyfLcsrCfkw',
#  '7jURkEKDVEm9sHueqUX0ko',
#  '7vujtNH3fnaNJ7AEyVtcrQ',
#  '5aAS1IwdIIdIF09CTioY0z',
#  '4e6a6yMJvPZItd0l4KTs1p',
#  '1FaEZe9E5eRYbpmwBDnYYK',
#  '3tIi3d8WRYlSb1aPs9Ro8H',
#  '6WISq0K95jxkhHu6oKHbng',
#  '6h5PAsRni4IRlxWr6uDPTP',
#  '0RTzJVkunbGwuRjXDFHnjf',
#  '5C4NMi4fPpdFPnMZVsyG8H',
#  '4b2tcjrG1qUkSdsqEFP2dB',
#  '5zATs59c3mikRxLK6ODE0p',
#  '7M4L1kiKMhtQZmpyO78DKd',
#  '5sT72aPBgt2W74loTXoqR1',
#  '5reLIvhRSxNNep5MlvKkYN',
#  '5lwBIwUdOBzVkRan4v5CmP',
#  '5gkmXJ8Jgwb1eRBNXj8Ufh',
#  '5RfVafaeEEiqC0Z3LsBaZw',
#  '4UQy41kC5LjzwQuiuWOpwA',
#  '4Wu62DoQg1ECGlDKDfo30R',
#  '6LHXb1sGs72iTmpSr0603b',
#  '4g6m1iaAsgdgDqgxGtvY0C',
#  '0dGhV1P8EXUJDNAckHGmI1',
#  '5yPEJ4UF90Km4KmLl2h4EE',
#  '1sh6lL6cmlcwhqZKGiKBua',
#  '1cVOEbvsf7N9Su4kZXFcYB',
#  '4VVzgTike7FW8OiUIDN7hk',
#  '6mhQ7eOHaV0ur2ooKTavW1',
#  '11WQasJcGWgh3mvR1UiBcm',
#  '72jIJDADnBLJKXV2yxv5N0',
#  '7LFs89i1kqjEzIvYR1WwJh',
#  '3vYhiBnAnCGL26yDB1QDQG',
#  '6cBVmDCjTVBtz171ouwYHg',
#  '3l6smflKi76lzGCnDYLe5Z',
#  '5hl5NU3fJXDsakF7pJga35',
#  '1lTePek6Xkel3k4Sjli6GB',
#  '1pAIlvyqOfnr4baZp2QGb9',
#  '6tEO7bieJDK8CAI0zplfu0',
#  '2XokuveOGJtpPvhIb3nLvy',
#  '4Vd3XrtbTMUDTT7UYc0o1F',
#  '6eJO3KPASyzKrVP9izfCEC',
#  '3VjFhqD2S4fUxWwAmO14gb',
#  '0wnXJy6kkLgLpcbFGnAXBI',
#  '2b9jjrVhyalVAu9jmlH5eG',
#  '6iMgWbghIWXSBdA7O6FJK0',
#  '7HSs4srn1qnZhh7WRWBVOk',
#  '19ow18zHKSdkjnEtsjFexD',
#  '74WjYdm3Lvbwnds4thYPUU',
#  '5cR6xfzyicyDyAr52zB48k',
#  '7DKv6FjD4xxeT4ZmEdec9W',
#  '0KFPsX30uBNCDpkgdz0JrV',
#  '2zGVfygrdGVKCZ54sxCaQH',
#  '1Oo7XEqkrwifJn17aA0ocF',
#  '4Z9cXGgviHafSAd7KzxABm',
#  '0Av4RcQUUitKvfC16IPodc',
#  '7xVtNzQhUKsRnfAeiSgpaf',
#  '2o0nyuoXnebqd1Eu9YM8le',
#  '5NQ41wfi4Pykv4eDTlAoIs',
#  '78GbhkxAc3BY3YHUe3Exyh',
#  '2knQh45joDt2zR8rDkJUrA',
#  '3CIWCPLeDYRZTrmAUGLw4k',
#  '6LkfxwQWOxY9cfQc1Zn8GJ',
#  '5fdp9rXfEixCGLM1Og4EN1',
#  '7kTVe6XhIveidvkt8nb7jK',
#  '5TKvSoHEXaCyk2GKM6pC3J',
#  '6iI5AH18vcQbGZszzvU3iG',
#  '168dPjh6dLw41wtn7MtTOQ',
#  '1xbCmCTvzd6nhbTJIg5pFu',
#  '2WpPklML14a0Lby1ZeqpIn',
#  '7E1ErYYCn0lYjHODZ1qGuB',
#  '1IwZPU3wcu7zQDZfHbaNYc',
#  '37vCG50piSFnHGVxwovlHC',
#  '1N06xKid6sYj3vRPbVQX1m',
#  '6Y3JXsXRN3Uh37225YxAKl',
#  '6hWOzchcVbVHuyA5Mb88bs',
#  '5bi8ryL6gy6a1BRXOf43y9',
#  '17Ymh369W4qCPXYzndYurO',
#  '64ZxBE1ZgK4C0lGljXzDcG',
#  '5GnRdw3oNKF8Mz6gdEcQLK',
#  '7HB1REjjalFLSXgXlAAwFs',
#  '4ZP3UMVksKg07IeeAjHkEy',
#  '4wgS4pen0Kej9PafGhUhMJ',
#  '2u9VGZmVz7Rm01SfDgzcfA',
#  '6Y2ID5LrizFmT8FL0BQEgG',
#  '1dFVnX4mJTnWubAPE8S3OR',
#  '3JAaETnjF592bbsgzUXAMp',
#  '5HMB40txXdGhVcPH5QxibE',
#  '26KykHLogeIep4OrurliDS',
#  '43bSKCMWHIuBsUVmQcDX1J',
#  '3qzNMOAMWvzMtl3aPv9rOB',
#  '4VpLwqzkob5lUeTE9rCqcK',
#  '0YNY0I3Hkspqe2NlhuWAQu',
#  '3eLlW0GegkXy3o92t51xaJ',
#  '3FMW2qArFQCYgkACKiqyeq',
#  '3O4Rl1D1MiLliQml4atM5D',
#  '5nyjJE5icW9rkqFGTZVhYR',
#  '26oID5JTkv963fmMQcsBef',
#  '0Gh45IbIKOG9IucFfrZqLT',
#  '4F2YKfoLAJfneX9LrNu6CC',
#  '7fUZ4ME47LBbbUrS2T2OTT',
#  '0FACbh0YPxCDWwSGxDydRu',
#  '3QZOoXdgDJ4Wg2H3wYP5MS',
#  '2ygeBLTP9uu3OW3VTulD8N',
#  '3zLTPuucd3e6TxZnu2dlVS',
#  '630zE7N1xPxdK2Zz4S3rPA',
#  '5UbN3fe9OB1p5KwjgUAHD4',
#  '2YFuTzAr02YYroPwI6vTi1',
#  '51xHvAUYQfhY29GcGlBM0n',
#  '1VYOAY7yevYbOj3AFupzSu',
#  '64ta7ZvTJeThz7Ns4LmAHS',
#  '0XkcuWNLacWDwEDmvq4CCy',
#  '7kwCAXd0GeQvWvfTgCjaNX',
#  '1bTXAKwE2Hztv13xTAhMQB',
#  '3tWp3CE214ezoQYNbjNKuX',
#  '1qNNg6vuSZqdeSWrnmqgS2',
#  '30bQxViotttoZ7x2iUP2L9',
#  '2H8nKAoMk1B7yKrd0uppGb',
#  '5cYyCE4b3T5TdQ3sGg8CYc',
#  '5mRrklQD0rvuN6sV10HfPn',
#  '1k82bzEjGy47GX0EbVPseH',
#  '2JOXTg7PdMetphuHjckQHI',
#  '4zdyJk5NEGXiWIZ87zfRVQ',
#  '5cR6xfzyicyDyAr52zB48k',
#  '55uJm9cRRUOWw48gga4MbC',
#  '4sfYQveGXUELiGaVWJELxZ',
#  '5knmhbxOpdAa9VqwoRSCln',
#  '78qIL92mSpGOm4gH7qgP3a',
#  '74WjYdm3Lvbwnds4thYPUU',
#  '178xNkaZ6wqtXw0tLTKlPI',
#  '4ErQ9so16QNxy0srB7vJE7',
#  '36I8o5FnN9f12DePkYYMQy',
#  '0ObV8vQoB8SJLf6vGv4xhB',
#  '5W7IiH2jDV6q6EQwBkq8ld',
#  '1aOiwLSEnhX9jxiwHuB0Sv',
#  '4hXaE6TgZCasb00D0BQyFa',
#  '1PT3zNAnVCN2CjeYaTcQH7',
#  '4qwnhaT0LcfJaRNGOhndaQ',
#  '1Y1WEeie6hox4GY2aiLLQ6',
#  '3t0yleDo23gh9vEjAfDbgX',
#  '25Iugb8Fr86UhfuvH4kOBn',
#  '3MAnojiEATIIumGcGs4scv',
#  '0a5ucFrCcAW2XnE9OINU6F',
#  '4HE2Ex0bjbj3YNXmV01OoM',
#  '1n8NKQRg8LVHy7oUhUgbFF',
#  '61OAY1Rtoc80jfqUwYI9qM',
#  '1KgJrBJv7nxhpPunJOXXgt',
#  '3ZzJMjqypHG6hn7SqtMUKc',
#  '3l1ZanpJ3jFQZMqATizqfE',
#  '3IBIwsWrPv2mpJa4SSfNGc',
#  '1Gas3HGCmNODYQiMU13LqL',
#  '07LWnpMdekmEjaipVc0PV7',
#  '1AY6q2jTRewDwaZZVKhRDa',
#  '6pWgRkpqVfxnj3WuIcJ7WP',
#  '2UcUL4jytfVpW0jSXi3Ggi',
#  '6ZFbXIJkuI1dVNWvzJzown',
#  '0bYiHGOcXqFaxa0H6ru88X',
#  '3vYg8WcDdRyiHfOpfjqlTa',
#  '41ujv4mhxlqR8nlnieDpDp',
#  '4fBqGaGJfEqTQDX4d7Hcil',
#  '3b9Dae2aPvOGKNOcdhj9CP',
#  '0l0e0M0j3T92RnVjka2UQ4',
#  '5E7gz5CbmUBNerBQg19ULz',
#  '086sjLPEqdKBgTxbTeCLCv',
#  '5bhbv1xIbk0SbfQ2MEXe8F',
#  '3JdD9wqvohYMjK6BmEHtTP',
#  '1CSaCKPIp2yCIDL3t7Fyau',
#  '2KdY6MVuZMwlqtW2JUdD4O',
#  '1PtQJZVZIdWIYdARpZRDFO',
#  '2LKOHdMsL0K9KwcPRlJK2v',
#  '5ihS6UUlyQAfmp48eSkxuQ',
#  '54eZmuggBFJbV7k248bTTt',
#  '0LtOwyZoSNZKJWHqjzADpW',
#  '7rrDSYbroZhV6aKkbYxiuG',
#  '0Xy1rQBbVieYCGcVYrpBJ9',
#  '0cz6XFt5fhHG0MQMAO97Gt',
#  '1yxfsbowmJcg2Lm82AzpG4',
#  '3jGlYaLUrPTZmzvNoZJNsD',
#  '47ugCLTk9gxAjV0gMcuVjv',
#  '4YURPo0m3UzWPXnGcLGvn1',
#  '0ovvdxdXgA1liaoO6HqzqH',
#  '60E1rDrHzNuFrXoIcwkDRL',
#  '2DD2pHlM7YhSf63FkjZNjC',
#  '3W7uzoZe8xxHVv75WvhHaZ',
#  '6lHWSoTxeUwBjxfcP0frD9',
#  '5u5lUvwZiPBHqVSJuXpxjd',
#  '20Ic8G42gzbjX89SjdKYTn',
#  '4if3aJ01ZXMajhwZctU06a',
#  '3nqQXoyQOWXiESFLlDF1hG',
#  '7ef4DlsgrMEH11cDZd32M6',
#  '6NAEpcvbmNdT0cWP3LFDcY',
#  '2tUBqZG2AbRi7Q0BIrVrEj',
#  '3k0DJq2HdWJqnqor8NX0ac',
#  '7B3z0ySL9Rr0XvZEAjWZzM',
#  '6MpCaSIOfqBqbMED4kXgNY',
#  '1HfsmNlg8xxhOr9N2i4Q0n',
#  '09DR0sHnQUhHOiSNttc1mv',
#  '5ECxiK4Vigo1yRRmAoZc1f',
#  '0kcZoSJ5Pxtal7zvitS5tb',
#  '3qaMDTwoBvdrxYvwgr9bgs',
#  '3iOL9G1ENCSNUw0X6yv5pF',
#  '6OG1S805gIrH5nAQbEOPY3',
#  '1bpnYrDCforv9ctJMzJRV8',
#  '0k4C2siRScZQAb7eIEQDI5',
#  '73RbfOTJIjHzi2pcVHjeHM',
#  '4Oun2ylbjFKMPTiaSbbCih',
#  '6c6WmIHcHlhccEwSFBhzNa',
#  '20BOju91NaEFK5Py4VJ2pp',
#  '38u74wUfcE5N47L2m9qYrZ',
#  '1lV3NdZCVc8wZ1wdv25Gw5',
#  '3KwLphYunPNCGwsCkr9OCq',
#  '5Ia7bTwJ1gTCFlztPvSHRC',
#  '4yD54gEYISBUYtgth3cSv2',
#  '61X73CJcpwGIxgQgKEXbw0',
#  '4BXnNaxLDGU1i3PK3iaWns',
#  '7zh9Phpu0GVQ6bCbPHiZAf',
#  '1kr0XkYcWe2HTuCFN3BuGA',
#  '3Eh3wDt6HDAx8mxDrOxIsQ',
#  '4YuPOUPQ3R15aSLO9wEiZK',
#  '0wLcWLY6JuNIuqJZxOu1Z7',
#  '6bAR0U4WV9uEBzuoNUzQSC',
#  '27mpDozgyKGFOvQZbStbdc',
#  '7CZqezgV2IyorX2tnR1hNt',
#  '0RnCUYXa7jhgTXtiMXF2PQ',
#  '2Vnw8zKmjhr1jczUeaqiQg',
#  '5KgbyD2lQQlIupAaPjgiXg',
#  '7GK2KVYH8FrTC9zehmjVMd',
#  '7Kszjzps0xbQXyo1pO4KfE',
#  '4fuwadVr6WOQoSydfA3fkR',
#  '0v9Wz8o0BT8DU38R4ddjeH',
#  '70kdJnm1X6eEM8DbWa8Mnc',
#  '6bAgNeCSmRrKtOaHHD5aSl',
#  '1VG1EM5OL6oObCFaaSzdo4',
#  '6rDKnKF7B4knjugixe44M0',
#  '0O14ArbnhIczAkSh0bIINk',
#  '3y9z5hBIbSkWW5A7nbpghC',
#  '5wGLQvq6JoxYZX7V3ymPS5',
#  '3V45D1XTTyVZFN3liYuik6',
#  '51NpP0s1nQLhoqWg49uh35',
#  '2goLsvvODILDzeeiT4dAoR',
#  '2him9rtohTgrRWxXS992To',
#  '27QvYgBk0CHOVHthWnkuWt',
#  '2Mpj1Ul5OFPyyP4wB62Rvi',
#  '4ENuIjI1dQOQGYkgIwQgSX',
#  '28STRBEo3Gp4EthtSk4MGW',
#  '5IVuqXILoxVWvWEPm82Jxr',
#  '2cbfCJFIX0RlIPNkLydHmj',
#  '5oCm9VmiP5bkYqm7EfVQg7',
#  '5PEcgEP0ldpnP4M3q5YP3T',
#  '3KwwE4sgCzMaKWq6QBebmX',
#  '3Qw29xE1UoPS5mdqoqVnWm',
#  '2mw5S1dAoQQVaPzzw3L4GP',
#  '3PFaFVWq5wucLu6s4baj9D',
#  '6MCm5U1tyfkaQvcGkbw3ov',
#  '2MtybE4np9hXIRNFBi9K4q',
#  '4KTtYhxFtFL7mBwnjkKfLm',
#  '0pi6mPEX2JZT9zO1tg7ESW',
#  '13F3T2TWkVW6oVZNnFc69e',
#  '5jBBOzlULSLS3J1WL646tB',
#  '5IwkF49z80NtBv4tJjYXge',
#  '0rcDFdi19NtKf9NbHxr0k9',
#  '0gorODYIUfyg83lBPnPbZs',
#  '2GcCFSXhiEkIya9tcAdk2M',
#  '6EHuOufBeL6vk3TvVJB5qo',
#  '5ZBeML7Lf3FMEVviTyvi8l',
#  '3KiexfmhxHvG5IgAElmTkd',
#  '2VmB1rF9FtfKUmFHDVnq8Q',
#  '0qsS2A3hwicJCLtcaR6JRQ',
#  '68BTFws92cRztMS1oQ7Ewj',
#  '3m7V717IKZqZLW5qUIOxdD',
#  '3evG0BIqEFMMP7lVJh1cSf',
#  '0voUr8lubIafUVJlauJxYF',
#  '6dGnYIeXmHdcikdzNNDMm2',
#  '2EqlS6tkEnglzr7tkKAAYD',
#  '4fUKE8EULjQdHF4zb0M8FO',
#  '2RnPATK99oGOZygnD2GTO6',
#  '25yQPHgC35WNnnOUqFhgVR',
#  '0hKRSZhUGEhKU6aNSPBACZ',
#  '6dGnYIeXmHdcikdzNNDMm2',
#  '3KfbEIOC7YIv90FIfNSZpo',
#  '5jgFfDIR6FR0gvlA56Nakr',
#  '0pNeVovbiZHkulpGeOx1Gj',
#  '3BQHpFgAp4l80e1XslIjNI',
#  '5ZBeML7Lf3FMEVviTyvi8l',
#  '7DD7eSuYSC5xk2ArU62esN',
#  '5Qe7NHxeLAn8KoLTNLSdwe',
#  '3zw4FTrVNfy2teEkV9FOvh',
#  '50xwQXPtfNZFKFeZ0XePWc',
#  '2xdvhChCtpYxyNApVJEUG1',
#  '2pcSENGQmdptFCBQ3HpKHe',
#  '0qcr5FMsEO85NAQjrlDRKo',
#  '52xJxFP6TqMuO4Yt0eOkMz',
#  '4Yxc55NX3tAXC2mHRAhtcW',
#  '1Jmqubf9kGkWeYQXQKImL5',
#  '6ToM0uwxtPKo9CMpbPGYvM',
#  '1Q5kgpp4pmyGqPwNBzkSrw',
#  '3MFFDRC4wTN9JNGtzXsZlN',
#  '4BVE5tIIpYabZcYCbephNW',
#  '2SiXAy7TuUkycRVbbWDEpo',
#  '2zYzyRzz6pRmhPzyfMEC8s',
#  '57bgtoPSgt236HzfBOd8kj',
#  '7LRMbd3LEoV5wZJvXT1Lwb',
#  '08mG3Y1vljYA6bvDt4Wqkj',
#  '1zwMYTA5nlNjZxYrvBB2pV',
#  '0gplL1WMoJ6iYaPgMCL0gX',
#  '5FgPwJ7Nh2FVmIXviKl2VF',
#  '62PaSfnXSMyLshYJrlTuL3',
#  '1c8gk2PeTE04A1pIDH9YMk',
#  '2wVWGFVkL5I3JGsoWBx2AZ',
#  '2m1hi0nfMR9vdGC8UcrnwU',
#  '1AdYZ6X00nXmO613Y7GJOl',
#  '1fJFuvU2ldmeAm5nFIHcPP',
#  '6WkSUgo1VdpzgtiXKlFPcY',
#  '02VBYrHfVwfEWXk5DXyf0T',
#  '7BqBn9nzAq8spo5e7cZ0dJ',
#  '55h7vJchibLdUkxdlX3fK7',
#  '60gTdTwaNtGAzIxKfeGVfJ',
#  '3xVZYkcuWalGudeKl861wb',
#  '3p7XQpdt8Dr6oMXSvRZ9bg',
#  '34gCuhDGsG4bRPIf9bb02f',
#  '7qiZfU4dY1lWllzX7mPBI3',
#  '1VdZ0vKfR5jneCmWIUAMxK',
#  '6ZZf5a8oiInHDkBe9zXfLP',
#  '5dPz35akJjPqb17yeqNwqH',
#  '5HCyWlXZPP0y6Gqq8TgA20',
#  '09CtPGIpYB4BrO8qb1RGsF',
#  '4umIPjkehX1r7uhmGvXiSV',
#  '4EDTT4kSqfpc0FKuxfNo2E',
#  '0SiywuOBRcynK0uKGWdCnn',
#  '24ySl2hOPGCDcxBxFIqWBu',
#  '0JNdS1n0ifOP25XvhwAMgM',
#  '5R8dQOPq8haW94K7mgERlO',
#  '6r2BECwMgEoRb5yLfp0Hca',
#  '4VqPOruhp5EdPBeR92t6lQ',
#  '3lPr8ghNDBLc2uZovNyLs9',
#  '7xyYsOvq5Ec3P4fr6mM9fD',
#  '429MqIq5nGH32feyRZHunv',
#  '0It6VJoMAare1zdV2wxqZq',
#  '6Rqn2GFlmvmV4w9Ala0I1e',
#  '7M9pPyt8Gr41THLhbz4NSB',
#  '0sjxRg1VlYfx4YG7uxurrq',
#  '5xRP5iyVdGglqlY4Vcjhkx',
#  '2eKwjJkBUaeaGq5GA1wTwc',
#  '2Bs4jQEGMycglOfWPBqrVG',
#  '4cluDES4hQEUhmXj6TXkSo',
#  '5T7ZFtCcOgkpjxcuaeZbw0',
#  '5O2P9iiztwhomNh8xkR9lJ',
#  '3NLnwwAQbbFKcEcV8hDItk',
#  '0daHbdrLvUmkh81rnolMcG',
#  ...]

# %%
song_ids_df = pd.DataFrame(song_ids)
song_ids_df
# Out:
#                            0
# 0     2gyxAWHebV7xPYVxqoi86f
# 1     2IGMVunIBsBLtEQyoI1Mu7
# 2     1BxfuPKGuaTgP7aM0Bbdwr
# 3     1vYXt7VSjH9JIM5oRRo7vA
# 4     7x9aauaA9cu6tyfpHnqDLo
# ...                      ...
# 5537  34gCuhDGsG4bRPIf9bb02f
# 5538  3U4isOIWM3VvDubwSI3y7a
# 5539  5Nm9ERjJZ5oyfXZTECKmRt
# 5540  1zNXF2svmdlNxfS5XeNUgr
# 5541  4Y4Gd3ty8uut6Qw43c7yJc
#
# [5542 rows x 1 columns]

# %%
song_ids_df.to_csv('song_ids.csv')

# %%
song_ids = pd.read_csv('song_ids.csv', index_col=[0])
song_ids
# Out:
#                            0
# 0     2gyxAWHebV7xPYVxqoi86f
# 1     2IGMVunIBsBLtEQyoI1Mu7
# 2     1BxfuPKGuaTgP7aM0Bbdwr
# 3     1vYXt7VSjH9JIM5oRRo7vA
# 4     7x9aauaA9cu6tyfpHnqDLo
# ...                      ...
# 5537  34gCuhDGsG4bRPIf9bb02f
# 5538  3U4isOIWM3VvDubwSI3y7a
# 5539  5Nm9ERjJZ5oyfXZTECKmRt
# 5540  1zNXF2svmdlNxfS5XeNUgr
# 5541  4Y4Gd3ty8uut6Qw43c7yJc
#
# [5542 rows x 1 columns]

# %%
sp.audio_features(song_ids.loc[0,'0'])[0]
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:879, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     878 try:
# --> 879     retries = retries.increment(method, url, response=response, _pool=self)
#     880 except MaxRetryError:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=2gyxAWHebV7xPYVxqoi86f (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:511, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     510 if isinstance(e.reason, ResponseError):
# --> 511     raise RetryError(e, request=request)
#     513 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=2gyxAWHebV7xPYVxqoi86f (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sp.audio_features(song_ids.loc[0,'0'])[0]
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:1734, in Spotify.audio_features(self, tracks)
#    1732 if isinstance(tracks, str):
#    1733     trackid = self._get_id("track", tracks)
# -> 1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/spotipy/client.py:307, in Spotify._internal_call(self, method, url, payload, params)
#     305     except (IndexError, AttributeError):
#     306         reason = None
# --> 307     raise SpotifyException(
#     308         429,
#     309         -1,
#     310         "%s:\n %s" % (request.path_url, "Max Retries"),
#     311         reason=reason
#     312     )
#     313 except ValueError:
#     314     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=2gyxAWHebV7xPYVxqoi86f:
#  Max Retries, reason: too many 429 error responses
